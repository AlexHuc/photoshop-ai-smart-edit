# %%
# !wget http://images.cocodataset.org/zips/train2017.zip
# Out:
# --2026-02-10 12:13:29--  http://images.cocodataset.org/zips/train2017.zip
# Resolving images.cocodataset.org (images.cocodataset.org)... 52.217.118.105, 16.15.201.66, 52.216.208.41, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.118.105|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 19336861798 (18G) [application/zip]
# Saving to: ‘train2017.zip’
#
# train2017.zip        23%[===>                ]   4,22G  --.-KB/s    in 37m 29s
#
# 2026-02-10 12:50:59 (1,92 MB/s) - Read error at byte 4526744341/19336861798 (Operation timed out). Retrying.
#
# --2026-02-10 12:51:00--  (try: 2)  http://images.cocodataset.org/zips/train2017.zip
# Connecting to images.cocodataset.org (images.cocodataset.org)|52.217.118.105|:80... connected.
# HTTP request sent, awaiting response... 206 Partial Content
# Length: 19336861798 (18G), 14810117457 (14G) remaining [application/zip]
# Saving to: ‘train2017.zip’
#
# ...
